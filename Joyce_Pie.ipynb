# %%
# %matplotlib inline
import matplotlib.pyplot as plt

print (type(plt))

dubliners_tokens=[3083, 3242, 2328, 1819, 2230, 3902, 2787, 3770, 1877, 2521, 3622, 5204, 4508, 7487, 15603]
dubliners_titles=['The Sisters', 'An Encounter', 'Araby', 'Eveline', 'After the Race', 'Two Gallants',
                  'The Boarding House', 'A Little Cloud', 'Counterparts', 'Clay', 'A Painful Case',
                  'IvyDay in the Committee Room', 'A Mother', 'Grace', 'The Dead']
plt.figure(figsize=(20,10))
temp=plt.pie(dubliners_tokens, labels=dubliners_titles)
# Out:
# <class 'module'>
