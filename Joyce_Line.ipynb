# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# %matplotlib inline

# %%
x=[1914,1916,1922,1939]
y=[115.72,95.9,77.6,81.7]

print(type(x))
print(type(y))
print(type(plt))
# Out:
# <class 'list'>
# <class 'list'>
# <class 'module'>

# %%
plt.plot(x,y)

# %%
y2=[77.373,76.1,74.8,62.8]
plt.plot(x,y,label='Yules K')
plt.plot(x,y2,label='RES')
plt.legend()
plt.xlabel('Publication Year')
plt.ylabel('Score')
plt.title('Yules K vs Readability Ease Score')
plt.grid()
plt.show()
